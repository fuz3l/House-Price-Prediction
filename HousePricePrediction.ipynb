# %% [markdown]
# <a href="https://colab.research.google.com/github/fuz3l/House-Price-Prediction/blob/main/HousePricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AmesHousing.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df[["Gr Liv Area", "Bedroom AbvGr", "Full Bath"]]
y = df['SalePrice']

# %%
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.2, random_state=0)

# %%
lm = LinearRegression()
lm.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(x_test)
# Out:
#       Gr Liv Area  Bedroom AbvGr  Full Bath
# 2216         1991              3          1
# 836           990              3          1
# 2396         1970              3          2
# 1962         1134              2          1
# 305          1178              2          1
# ...           ...            ...        ...
# 2352         1083              2          1
# 2027         2526              5          2
# 867          1725              3          2
# 2590         2039              3          1
# 1418         2329              4          2
#
# [586 rows x 3 columns]

# %%
pred = lm.predict(x_test)

# %%
print(pred)
# Out:
# [179144.5130703  107033.44632393 211947.86672868 102498.15910718
#  123220.44129771 166821.75892199 163444.45852027 181561.44237643
#   98843.27250766 244655.24834153 273060.86197442 199840.13843471
#  114063.1415099  126084.14444956 209113.31221821 108167.26812812
#  146036.916388   205031.55372313 108167.26812812 109754.61865398
#  155483.54088011 171774.67134307 217390.21138878 217843.74011046
#  211267.57364616 253018.8728664  223286.08477056 210220.47719628
#  235871.50679705 178386.74132471 195847.59710921 121746.47295226
#  182695.26418062 155987.89143874 118711.81090707 114063.1415099
#  164100.58659194 210700.66274407 224760.053116   189951.72372743
#  308271.89824771 252514.52230777 261495.8795717  217503.5935692
#  138413.65347383 286893.48798551 185303.05433026 151479.26104811
#  176119.09771633 112562.51633834 176372.51890329 133311.45535498
#  134131.78744403 215489.37114778 171697.19268    208092.87259444
# ...

# %%
plt.figure(figsize=(8, 5))

plt.scatter(x_test["Gr Liv Area"], y_test, color='blue', label='Actual Prices')
plt.scatter(x_test["Gr Liv Area"], pred, color='red', label='Predicted Prices')

plt.title('House Price Prediction')
plt.xlabel('House Size (sq ft)')
plt.ylabel('Price')
plt.legend()
plt.show()
